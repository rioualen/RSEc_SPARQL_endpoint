# %% [markdown]
# ## Loading EDAM into an RDFlib graph

# %%
from rdflib import ConjunctiveGraph
import os

# %%
#edam_version = 'https://edamontology.org/EDAM_1.25.owl'
#edam_version = 'https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl'

edam_version = 'https://github.com/edamontology/edamontology/raw/main/EDAM_dev.owl'

kg = ConjunctiveGraph()
kg.parse(edam_version, format='xml')

print(str(len(kg)) + ' triples in the EDAM triple store')
# Out:
# 38792 triples in the EDAM triple store

# %%
## temp - get all deprecated classes

query="""
PREFIX edam: <http://edamontology.org/>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?label ?entity WHERE {
    # ?entity owl:deprecated true ;
        rdfs:label ?label .
}
"""

results = kg.query(query)

f = open("deprecated_classes.tsv", "a")

for r in results :
#    print(f"{r['entity']} - {r['label']} ") 
    f.write(f"{r['entity']}\t{r['label']}\t{'deprecated'}\n")

f.close()

# %% [markdown]
# ## TESTS EDAM Control Room

# %%
## get topics from url 2026-01-02

query="""
PREFIX edam: <http://edamontology.org/>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?label ?entity WHERE {
    # ?entity rdfs:subClassOf+ edam:topic_0003 ;
                rdfs:label ?label .
}
"""
results = kg.query(query)

print(results)
#query = os.path.dirname(".")  + "../queries/no_wikipedia_link_topic.rq"

#with open(query, "r") as f:
#    query = f.read()
#    results = kg.query(query)
#f.close()


for r in results :
#      print(r)
    print(f"{r['entity']}\t{r['label']} ")
 

#for stmt in g:
#    pprint.pprint(stmt)


## write to file
path = "/Users/rioualen/Desktop/" + "edamtopics.tsv"
#resultfile = path  + "edamtopics.tsv"
with open(path, "w") as f:
    for r in results :
        f.write(f"{r['entity']}\t{r['label']}\n")
f.close()
# Out:
# ...
# http://edamontology.org/topic_0605	Informatics
# http://edamontology.org/topic_0089	Ontology and terminology
# http://edamontology.org/topic_0091	Bioinformatics
# http://edamontology.org/topic_0607	Laboratory information management
# http://edamontology.org/topic_2258	Cheminformatics
# http://edamontology.org/topic_3931	Chemometrics
# http://edamontology.org/topic_3063	Medical informatics
# http://edamontology.org/topic_3489	Database management
# http://edamontology.org/topic_3948	Immunoinformatics
# http://edamontology.org/topic_4045	Cybersecurity
# http://edamontology.org/topic_4046	Version control
# http://edamontology.org/topic_4047	Software management
# http://edamontology.org/topic_3068	Literature and language
# http://edamontology.org/topic_0218	Natural language processing
# http://edamontology.org/topic_3071	Data management
# http://edamontology.org/topic_0219	Data curation and archival
# http://edamontology.org/topic_0769	Workflows
# ...

# %% [markdown]
# ### Topic with no wikipedia link

# %%
## Get topics that don't have a wikipedia link as a 'seeAlso' attribute

query="""
PREFIX edam: <http://edamontology.org/>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?label ?entity WHERE {
    # ?entity rdfs:subClassOf+ edam:topic_0003 ;
                rdfs:label ?label .
        FILTER NOT EXISTS {
        # ?entity rdfs:seeAlso ?seealso .
        FILTER (regex(str(?seealso), "wikipedia.org", "i"))
       } .
}
"""
#results = kg.query(query)

query = os.path.dirname(".")  + "../queries/no_wikipedia_link_topic.rq"

with open(query, "r") as f:
    query = f.read()
    results = kg.query(query)
f.close()


for r in results :
    print(f"{r['entity']} - {r['label']} ")
# Out:
# http://edamontology.org/topic_4047 - Software management
# http://edamontology.org/topic_3068 - Literature and language
# http://edamontology.org/topic_3345 - Data identity and mapping
# http://edamontology.org/topic_3923 - Genome resequencing
# http://edamontology.org/topic_3520 - Proteomics experiment
# http://edamontology.org/topic_3524 - Simulation experiment
# http://edamontology.org/topic_0123 - Protein properties
# http://edamontology.org/topic_3510 - Protein sites, features and motifs
# http://edamontology.org/topic_0157 - Sequence composition, complexity and repeats
# http://edamontology.org/topic_0632 - Probes and primers
# http://edamontology.org/topic_0160 - Sequence sites, features and motifs
# http://edamontology.org/topic_3892 - Biomolecular simulation
# http://edamontology.org/topic_3374 - Biotherapeutics
# http://edamontology.org/topic_3393 - Quality affairs

# %% [markdown]
# ### Links not literals

# %%
query = """
## Checks that all webpage and doi are declared as literal links.

PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    
SELECT DISTINCT ?entity ?property ?label ?value WHERE {
    VALUES ?property {
                    <http://edamontology.org/citation>
                    <http://edamontology.org/documentation>
                    <http://edamontology.org/information_standard>
                    <http://edamontology.org/oldParent>
                    <http://edamontology.org/ontology_used>
                    <http://edamontology.org/organisation>
                    <http://www.geneontology.org/formats/oboInOwl#consider>
                    <http://www.geneontology.org/formats/oboInOwl#inSubset>
                    <http://www.geneontology.org/formats/oboInOwl#replacedBy>
                    <http://www.w3.org/2000/01/rdf-schema#seeAlso>
                    <http://www.w3.org/2000/01/rdf-schema#subClassOf>
                    <http://www.w3.org/2000/01/rdf-schema#subPropertyOf>
                    <http://www.w3.org/2002/07/owl#annotatedProperty>
                    <http://www.w3.org/2002/07/owl#inverseOf>
                    <http://www.w3.org/2002/07/owl#disjointWith>
                    <http://www.w3.org/2000/01/rdf-schema#domain>
                    <http://www.w3.org/2000/01/rdf-schema#range>


}

# ?entity ?property ?value .

FILTER isLiteral(?value) 
# ?entity rdfs:label ?label .

}
#ORDER BY ?entity
"""

#results = kg.query(query)

query = os.path.dirname(".")  + "../queries/literal_links.rq"

with open(query, "r") as f:
    query = f.read()
    results = kg.query(query)
f.close()


for r in results :
    print(f"{r['entity']} - {r['label']} - {r['property']} - {r['value']} ")
# Out:
# http://edamontology.org/format_1997 - PHYLIP format - http://edamontology.org/documentation - http://www.bioperl.org/wiki/PHYLIP_multiple_alignment_format
# http://edamontology.org/format_1998 - PHYLIP sequential - http://edamontology.org/documentation - http://www.bioperl.org/wiki/PHYLIP_multiple_alignment_format
# http://edamontology.org/format_3462 - CRAM - http://edamontology.org/documentation - http://www.ebi.ac.uk/ena/software/cram-usage#format_specification http://samtools.github.io/hts-specs/CRAMv2.1.pdf
# http://edamontology.org/format_3484 - ebwt - http://edamontology.org/documentation - https://github.com/BenLangmead/bowtie/blob/master/MANUAL
# http://edamontology.org/format_3485 - RSF - http://edamontology.org/documentation - http://www.molbiol.ox.ac.uk/tutorials/Seqlab_GCG.pdf
# http://edamontology.org/format_3487 - BSML - http://edamontology.org/documentation - http://rothlab.ucdavis.edu/genhelp/chapter_2_using_sequences.html#_Creating_and_Editing_Single_Sequenc
# ...

# %% [markdown]
# ### Format property missing

# %%
## testing format_property_missing.rq

## Checks the no mandatory property for format are missing (documentation,is_format_of). 
## To make sure not to miss the inherited "is_format_of" property from parent concept, 
## a CONSTRUCT query is used to add the missing triplets to the graph.

query="""
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?entity ?label ?property WHERE
{
  
    # ?entity rdfs:subClassOf+ edam:format_1915 .
    # ?entity rdfs:label ?label .
    {
        VALUES ?property { edam:documentation }
        FILTER NOT EXISTS {?entity ?property ?value .}
    }
    UNION
    {
        VALUES ?property { edam:is_format_of }
        FILTER NOT EXISTS {    
            # ?entity rdfs:subClassOf ?restriction . 
            # ?restriction rdf:type owl:Restriction ; 
                owl:onProperty ?property  ; 
                owl:someValuesFrom ?data . }
    }
}
"""

#results = kg.query(query)

query = os.path.dirname(".")  + "../queries/format_property_missing.rq"

with open(query, "r") as f:
    query = f.read()
    results = kg.query(query)
f.close()


for r in results :
    print(f"{r['entity']} - {r['property']} - {r['label']} ")
# Out:
# http://edamontology.org/format_2330 - http://edamontology.org/documentation - Textual format
# http://edamontology.org/format_2330 - http://edamontology.org/is_format_of - Textual format
# http://edamontology.org/format_1196 - http://edamontology.org/is_format_of - SMILES
# http://edamontology.org/format_1200 - http://edamontology.org/documentation - smarts
# http://edamontology.org/format_1200 - http://edamontology.org/is_format_of - smarts
# http://edamontology.org/format_1197 - http://edamontology.org/documentation - InChI
# http://edamontology.org/format_1197 - http://edamontology.org/is_format_of - InChI
# http://edamontology.org/format_1198 - http://edamontology.org/documentation - mf
# http://edamontology.org/format_1198 - http://edamontology.org/is_format_of - mf
# http://edamontology.org/format_1199 - http://edamontology.org/documentation - InChIKey
# http://edamontology.org/format_1199 - http://edamontology.org/is_format_of - InChIKey
# ...

# %% [markdown]
# ### Duplicate in concept

# %%
##testing duplicate_in_concept.rq
query="""
## Problem: An entity shares a label with an synonym. This causes ambiguity. Excludes deprecated entities.
## Suggestion: exclude comment and documentation fields

PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?entity ?property ?property2 ?value ?label WHERE {
    VALUES ?property {oboInOwl:hasDefinition
                      oboInOwl:hasExactSynonym
                      oboInOwl:hasNarrowSynonym
                      oboInOwl:hasBroadSynonym
                      rdfs:comment
                      rdfs:label
                      edam:documentation
                        }
    VALUES ?property2 {oboInOwl:hasDefinition
                      oboInOwl:hasExactSynonym
                      oboInOwl:hasNarrowSynonym
                      oboInOwl:hasBroadSynonym
                      rdfs:comment
                      rdfs:label
                      edam:documentation
                        }

    # ?entity a owl:Class . 
    # ?entity ?property ?value .
    # ?entity ?property2 ?value2 .
#    FILTER (?value = ?value2)
    FILTER ( UCASE(str(?value)) = UCASE(str(?value2)) )

    FILTER (?property != ?property2)    
    # ?entity rdfs:label ?label .
  
}
# ORDER BY ?value

"""

results = kg.query(query)

for r in results :
    print(f"{r['entity']} - {r['property']} - {r['label']} ")
